# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取 CSV 文件
file_path = '/Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/lmsys_chat_1m_dataset.csv'
df = pd.read_csv(file_path)

# 提取 question_length 和 answer_length
question_length = df['question_length']
answer_length = df['answer_length']

# 绘制 question_length 和 answer_length 的柱状图
plt.figure(figsize=(12, 6))

# 设置子图，第一部分绘制 question_length 的柱状图
plt.subplot(1, 2, 1)
plt.hist(question_length, bins=50, color='blue', alpha=0.7, edgecolor='black')
plt.title('Distribution of Question Length')
plt.xlabel('Question Length')
plt.ylabel('Frequency')

# 标注 mean 和 median
mean_q = question_length.mean()
median_q = question_length.median()
plt.axvline(mean_q, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_q:.2f}')
plt.axvline(median_q, color='green', linestyle='dashed', linewidth=2, label=f'Median: {median_q:.2f}')
plt.legend()

# 第二部分绘制 answer_length 的柱状图
plt.subplot(1, 2, 2)
plt.hist(answer_length, bins=50, color='orange', alpha=0.7, edgecolor='black')
plt.title('Distribution of Answer Length')
plt.xlabel('Answer Length')
plt.ylabel('Frequency')

# 标注 mean 和 median
mean_a = answer_length.mean()
median_a = answer_length.median()
plt.axvline(mean_a, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_a:.2f}')
plt.axvline(median_a, color='green', linestyle='dashed', linewidth=2, label=f'Median: {median_a:.2f}')
plt.legend()

# 显示图表
plt.tight_layout()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取 CSV 文件
file_path = '/Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/lmsys_chat_1m_dataset.csv'
df = pd.read_csv(file_path)

# 提取 question_length 和 answer_length
question_length = df['question_length']
answer_length = df['answer_length']

# 绘制 question_length 和 answer_length 的柱状图
plt.figure(figsize=(12, 6))

# 设置子图，第一部分绘制 question_length 的柱状图
plt.subplot(1, 2, 1)
plt.hist(question_length, bins=50, color='blue', alpha=0.7, edgecolor='black')
plt.title('Distribution of Question Length')
plt.xlabel('Question Length')
plt.ylabel('Frequency')

# 标注 mean 和 median
mean_q = question_length.mean()
median_q = question_length.median()
plt.axvline(mean_q, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_q:.2f}')
plt.axvline(median_q, color='green', linestyle='dashed', linewidth=2, label=f'Median: {median_q:.2f}')
plt.legend()

# 对数坐标轴
plt.yscale('log')

# 第二部分绘制 answer_length 的柱状图
plt.subplot(1, 2, 2)
plt.hist(answer_length, bins=50, color='orange', alpha=0.7, edgecolor='black')
plt.title('Distribution of Answer Length')
plt.xlabel('Answer Length')
plt.ylabel('Frequency')

# 标注 mean 和 median
mean_a = answer_length.mean()
median_a = answer_length.median()
plt.axvline(mean_a, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_a:.2f}')
plt.axvline(median_a, color='green', linestyle='dashed', linewidth=2, label=f'Median: {median_a:.2f}')
plt.legend()

# 对数坐标轴
plt.yscale('log')

# 显示图表
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# 读取原始 CSV 文件
file_path = '/Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/lmsys_chat_1m_dataset.csv'
df = pd.read_csv(file_path)

# 筛选出 question_length 小于 500 的行
filtered_df = df[df['question_length'] < 500]

# 保存筛选后的数据到新的 CSV 文件
output_path = '/Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/input<500.csv'
filtered_df.to_csv(output_path, index=False)

print(f"Filtered CSV saved to: {output_path}")
print(f"数目:{len(filtered_df)}")
# Out:
# Filtered CSV saved to: /Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/input<500.csv
# 数目:984465

# %%
import pandas as pd

# 读取原始 CSV 文件
file_path = '/Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/lmsys_chat_1m_dataset.csv'
df = pd.read_csv(file_path)

# 筛选出 question_length 小于 500 的行
filtered_df = df[df['question_length'] < 250]

# 保存筛选后的数据到新的 CSV 文件
output_path = '/Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/input<250.csv'
filtered_df.to_csv(output_path, index=False)

print(f"Filtered CSV saved to: {output_path}")
print(f"数目:{len(filtered_df)}")
# Out:
# Filtered CSV saved to: /Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/input<250.csv
# 数目:922959

# %%
import pandas as pd

# 读取原始 CSV 文件
file_path = '/Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/lmsys_chat_1m_dataset.csv'
df = pd.read_csv(file_path)

# 筛选出 question_length 小于 500 的行
filtered_df = df[df['question_length'] < 100]

# 保存筛选后的数据到新的 CSV 文件
output_path = '/Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/input<100.csv'
filtered_df.to_csv(output_path, index=False)

print(f"Filtered CSV saved to: {output_path}")
print(f"数目:{len(filtered_df)}")
# Out:
# Filtered CSV saved to: /Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/input<100.csv
# 数目:796434

# %%
import pandas as pd

# 读取原始 CSV 文件
file_path = '/Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/lmsys_chat_1m_dataset.csv'
df = pd.read_csv(file_path)

# 筛选出 question_length 小于 100 且 answer_length 小于 400 的行
filtered_df = df[(df['question_length'] < 200) & (df['answer_length'] < 200)]

# 保存筛选后的数据到新的 CSV 文件
output_path = '/Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/input<200_output<200.csv'
filtered_df.to_csv(output_path, index=False)

print(f"Filtered CSV saved to: {output_path}")
print(f"数目:{len(filtered_df)}")
# Out:
# Filtered CSV saved to: /Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/input<200_output<200.csv
# 数目:539969

# %%
import pandas as pd

# 读取原始 CSV 文件
file_path = '/Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/lmsys_chat_1m_dataset.csv'
df = pd.read_csv(file_path)

# 筛选出 question_length 小于 100 且 answer_length 小于 400 的行
filtered_df = df[(df['question_length'] < 100) & (df['answer_length'] < 100)]

# 保存筛选后的数据到新的 CSV 文件
output_path = '/Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/input<100_output<100.csv'
filtered_df.to_csv(output_path, index=False)

print(f"Filtered CSV saved to: {output_path}")
print(f"数目:{len(filtered_df)}")
# Out:
# Filtered CSV saved to: /Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/input<100_output<100.csv
# 数目:335942

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取 CSV 文件
file_path = '/Users/luogan/Desktop/vidur_or/lmsys_chat_1m_dataset/output_trace/input<100_output<100.csv'
df = pd.read_csv(file_path)

# 提取 question_length 和 answer_length
question_length = df['question_length']
answer_length = df['answer_length']

# 绘制 question_length 和 answer_length 的柱状图
plt.figure(figsize=(12, 6))

# 设置子图，第一部分绘制 question_length 的柱状图
plt.subplot(1, 2, 1)
plt.hist(question_length, bins=50, color='blue', alpha=0.7, edgecolor='black')
plt.title('Distribution of Question Length')
plt.xlabel('Question Length')
plt.ylabel('Frequency')

# 标注 mean 和 median
mean_q = question_length.mean()
median_q = question_length.median()
plt.axvline(mean_q, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_q:.2f}')
plt.axvline(median_q, color='green', linestyle='dashed', linewidth=2, label=f'Median: {median_q:.2f}')
plt.legend()

# 对数坐标轴
plt.yscale('log')

# 第二部分绘制 answer_length 的柱状图
plt.subplot(1, 2, 2)
plt.hist(answer_length, bins=50, color='orange', alpha=0.7, edgecolor='black')
plt.title('Distribution of Answer Length')
plt.xlabel('Answer Length')
plt.ylabel('Frequency')

# 标注 mean 和 median
mean_a = answer_length.mean()
median_a = answer_length.median()
plt.axvline(mean_a, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_a:.2f}')
plt.axvline(median_a, color='green', linestyle='dashed', linewidth=2, label=f'Median: {median_a:.2f}')
plt.legend()

# 对数坐标轴
plt.yscale('log')

# 显示图表
plt.tight_layout()
plt.show()
